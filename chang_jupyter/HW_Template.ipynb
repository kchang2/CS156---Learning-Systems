# %% [markdown]
# # HW
# ## CS156, Kai Chang

# %% [markdown]
# ### Question 1
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 2
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 3
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 4
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 5
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 6
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 7
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 8
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 9
# Answer Choice: <br>
# Reasoning:

# %% [markdown]
# ### Question 10
# Answer Choice: <br>
# Reasoning:
